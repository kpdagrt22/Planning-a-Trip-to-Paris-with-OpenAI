# %% [markdown]
# ![eiffel-tower](images/eiffel-tower.png)
#
# As a distinguished AI Developer, you've been selected by Peterman Reality Tours, an internationally acclaimed tourism company, to undertake an influential project. This project requires you to harness the potential of OpenAI's API, to create an AI-powered travel guide for the culturally rich city of Paris.
#
# Your creation will become a virtual Parisian expert, delivering valuable insights into the city's iconic landmarks and hidden treasures. The AI will respond intelligently to a set of common questions, providing a more engaging and immersive travel planning experience for the clientele of Peterman Reality Tours.
#
# The ultimate aspiration is a user-friendly, AI-driven travel guide that significantly enhances the exploration of Paris. Users will be able to pre-define their questions and receive well-informed answers from the AI, providing a seamless and intuitive travel planning process.

# %%
import os
from openai import OpenAI

# Define the model to use
model = "gpt-4o-mini"

# Define the client
client = OpenAI()

# Conversation history
conversation = [
    {
        "role": "system",
        "content": "You are a virtual Parisian expert travel guide created by Peterman Reality Tours. Provide accurate and concise responses to questions about Paris landmarks using the OpenAI API with a temperature of 0.0 and a maximum of 100 tokens. Focus on delivering valuable insights for an immersive travel experience."
    }
]

# Function to add user message and get response
def get_response(user_message):
    conversation.append({"role": "user", "content": user_message})
    response = client.chat.completions.create(
        model=model,
        messages=conversation,
        temperature=0.0,
        max_tokens=100
    )
    assistant_message = response.choices[0].message.content
    conversation.append({"role": "assistant", "content": assistant_message})
    return assistant_message

# Example usage
print("Welcome to Peterman Reality Tours' Parisian Travel Guide!")
while True:
    user_input = input("Ask a question about Paris (or type 'exit' to quit): ")
    if user_input.lower() == 'exit':
        break
    response = get_response(user_input)
    print("Guide: ", response)
# Out:
# Welcome to Peterman Reality Tours' Parisian Travel Guide!
# Ask a question about Paris (or type 'exit' to quit): what are the best places in paris
# Guide:  Some of the best places in Paris include:
#
# 1. **Eiffel Tower** - Iconic symbol of Paris with stunning views.
# 2. **Louvre Museum** - Home to thousands of artworks, including the Mona Lisa.
# 3. **Notre-Dame Cathedral** - Gothic architecture and historical significance.
# 4. **Montmartre** - Artistic neighborhood with the Sacré-Cœur Basilica.
# 5. **Champs-Élysées and Arc de Triomphe** - Famous avenue and monumental arch.
#
# Ask a question about Paris (or type 'exit' to quit): tell me about eiffel tower
# Guide:  The Eiffel Tower, designed by Gustave Eiffel, was completed in 1889 for the Exposition Universelle. Standing at 1,083 feet, it was the tallest man-made structure until 1930. Visitors can access three levels, with restaurants and observation decks offering panoramic views of Paris. Illuminated at night, it’s a symbol of romance and innovation.
# Ask a question about Paris (or type 'exit' to quit): exit
